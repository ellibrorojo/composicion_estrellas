# %%
import sys  
sys.path.append(r'../source')  
import utils
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Origen de los datos

# %% [markdown]
# # Análisis exploratorio sin entrar en el contenido

# %% [markdown]
# En esta sección vamos a explorar el dataset en crudo. A este objeto lo llamaremos data_raw_0, y es el resultado de leer el fichero original, Electronics_5.json, y trasladarlo a un DataFrame de Pandas. Por el camino realizamos un mínimo procesamiento que consiste en los siguiente:
# * Transformamos el campo fecha en año, pues no necesitamos tanto detalle.
# * Eliminamos algunos campos que no son de interés para este trabajo, concretamente los siguientes:
#   * 'vote'
#   * 'verified'
#   * 'style'
#   * 'reviewerName'
#   * 'unixReviewTime'
#   * 'image'
#   * 'reviewTime'
# * Sustituimos los nans por cadenas vacías. Esto lo hacemos tras comprobar que los únicos campos que presentan nans son los campos 'review' o 'summary', donde resulta más razonable, en el contexto de análisis de texto, que dichos campos sean cadenas vacías.
#
# Vamos a mostrar varias representaciones del dataset para conocerlo un poco mejor. Enseguida veremos que el fichero Electronics_5.json contiene un gran sesgo hacia opiniones con una alta valoración. Este efecto es esperado, pues se conoce que las valoraciones de los productos en Amazon suelen altas. Ref: https://minimaxir.com/2014/06/reviewing-reviews/
#
# Debido al análisis que se pretende hacer en este trabajo, eliminaremos el sesgo, dejando la misma cantidad de opiniones por cada valoración. Por este motivo el análisis exploratorio aparece dos veces, la primera sobre el dataset con sesgo y la segunda sin sesgo en la valoración.

# %%
data_raw_0 = utils.electronics_5_to_raw_data_0()

# %% [markdown]
# A continuación comprobamos que la distribución de puntuaciones está desplazada hacia valoraciones altas. Especialmente llamativa es la cantidad de opiniones con una valoración de 5 estrellas.

# %%
utils.perform_eda(data_raw_0, 'rating_distribution')

# %% [markdown]
# Comprobamos que si mostramos la misma información pero tomando la puntuación mediana por producto el efecto ese el mismo, incluso es algo más pronunciado:

# %%
utils.perform_eda(data_raw_0, 'rating_distribution_item')

# %% [markdown]
# Veamos cuándo se registraron las opiniones de que disponemos:

# %%
utils.perform_eda(data_raw_0, 'opinions_per_year')

# %% [markdown]
# El registro comienza en 1999 y termina en 2018, con un pico muy pronunciado entorno a los años 2014-2015.

# %% [markdown]
# Veamos ahora cuántas opiniones suelen tener los artículos.

# %%
utils.perform_eda(data_raw_0, 'opinions_per_item')

# %% [markdown]
# Nótese la necesidad de una escala logarítmica. Si bien hay algunos artículos con una gran cantidad de opiniones (del orden de miles), también podemos ver que la mediana está situada en 9 opiniones.

# %% [markdown]
# Igual que con los artículos, veamos ahora cuántas opiniones hay por usuario.

# %%
utils.perform_eda(data_raw_0, 'opinions_per_user')

# %% [markdown]
# Vemos que una gran cantidad de usuarios tienen apenas unas pocas opiniones.

# %% [markdown]
# ¿Cómo es la dispersión en las puntuaciones? Lo vemos en el siguiente boxplot:

# %%
utils.perform_eda(data_raw_0, 'rating_sd_per_item')

# %% [markdown]
# La desviación estándar de las opiniones, calculada a nivel de artículo, tiene una mediana de 1, si bien puede llegar a ser bastante grande. Ninguna sorpresa aquí.

# %% [markdown]
# Veamos cuál es la longitud media de las opiniones según la puntuación, así como la proporción entre el resumen y el cuerpo de la opinión.

# %%
utils.perform_eda(data_raw_0, 'summary_review_length_comparison_per_rating')

# %%
utils.perform_eda(data_raw_0, 'text_length_per_rating')

# %% [markdown]
# A continuación eliminamos el sesgo y repetimos la fase EDA.
#
# Para eliminar el sesgo tomamos todas las opiniones de 2 estrellas, pues es el grupo menos poblado, y realizamos un sampleo aleatorio sobre el resto del datset. Tras este sampleo, el contenido del fichero Electronics_5.json que finalmente empleamos es aproximadamente un cuarto del total.

# %%
data_raw_1 = utils.remove_rating_bias_from_raw_data(data_raw_0)

# %%
utils.perform_eda(data_raw_1, 'rating_distribution')

# %%
utils.perform_eda(data_raw_1, 'rating_distribution_item')

# %%
utils.perform_eda(data_raw_1, 'opinions_per_year')

# %%
utils.perform_eda(data_raw_1, 'opinions_per_item')

# %%
utils.perform_eda(data_raw_1, 'opinions_per_user')

# %%
utils.perform_eda(data_raw_1, 'rating_sd_per_item')

# %%
utils.perform_eda(data_raw_1, 'summary_review_length_comparison_per_rating')

# %%
utils.perform_eda(data_raw_1, 'text_length_per_rating')

# %% [markdown]
# # Preparación de los datos

# %% [markdown]
# En esta sección tratamos el procesamiento de los datos. Los preparamos y le damos la estructura adecuada para realizar un análisis sobre ellos.
#
# El objeto resultante del procesamiento lo llamaré odf (Opinion Data Frame) y será una pieza clave pues todos los análisis se harán sobre el mismo. Este objeto, de tipo pandas.DataFrame, contendrá tantas filas como opiniones (aproximadamente 1.5 millones) y los campos son los siguientes:
# * doc_number
# * rating
# * text
# * summary_raw
# * review_raw
# * summary_tokens_length

# %% [markdown]
# La construcción del objeto odf se realiza bajo la función execute_preprocessing_pipeline, que es una rutina que va ejecutando las distintas transformaciones que sufre el dataset suministrado, data_raw_1, hasta devolver el odf completo.

# %%
odf = utils.execute_preprocessing_pipeline(data_raw_1, False)
#odf = utils.load_latest_odf(nrows=1532805, is_false=True)

# %% [markdown]
# # Análisis

# %% [markdown]
# El análisis que se lleva a cabo en este proyecto tiene por objetivo encontrar y mostrar de la mejor manera posible las relaciones que se establecen entre opiniones y temas. Por tanto, para realizar esta tarea vamos a necesitar dos partes previas a la extracción de insights:
# * La detección, definición y construcción de temas
# * La asignación de temas a opiniones
#
# En las siguientes secciones se presentan las herramientas desarrolladas y los objetos definidos para llevar a cabo ambas partes.
#
# Antes de ello, vamos a definir los elementos que van a ir apareciendo.
# * Tema: definimos un tema como un elemento de negocio. Cada tema tratará de representar una parte del proceso de compra de un producto en un comercio electrónico. Por la manera en que se definen, los temas están naturalmente compuestos por subtemas (aunque no siempre hay una barrera clara entre subtemas) y estos, a su vez, por combinaciones de keywords. Los veremos más adelante pero, por poner un ejemplo, uno de los temas trata de la experiencia en la entrega del paquete. Algunos temas se definen por parejas (un tema para la experiencia positiva y otro para la negativa) y otros temas no tienen esa dualidad.
# * Wordset: es el conjunto de palabras clave que constituyen un tema. No se trata simplemente de una lista sino que hay una cierta lógica, unas relaciones que deben cumplir los tokens con tal de considerarse un tema.
# * Token: en este trabajo un token puede ser una palabra o un bigrama. Ejemplos de token pueden ser "package" o "works_great".
# * Opinión: cuando usamos la palabra opinión nos referimos al objeto "Opinión", no al texto que escribe el usuario. La diferencia es que, en este análisis, la opinión es un objeto compuesto por varios campos: rating, review y summary.
# * Rating: es la puntuación de una opinión. Siempre tiene un valor entre 1 y 5.
# * Review: es el texto (largo) que escribe el usuario. Es, básicamente, lo que exploraremos para tratar de asignar temas a opiniones.
# * Summary: es el resumen o el título de la review. Como hemos visto en el EDA, la longitud del summary suele ser bastante inferior a la de la review. También exploramos en los summaries para asignar temas a opiniones.
# * Hit: asignación de un tema a una opinión.

# %% [markdown]
# # Herramientas y objetos

# %% [markdown]
# ## Detección, definición y construcción de temas

# %% [markdown]
# Tras varios intentos fallidos de emplear métodos de Topic Modelling para la detección de los temas, decidí construir una metodología propia. Definí un tema como la estructura siguiente:

# %%
tema =  {
            'name': 'nombre del tema'
            , 'wordset':
            {
                'ands':  []
                , 'ors': [
                            {
                            'syn0': [],
                            'syn1': [],
                            'syn2': [],
                            'nots': []
                            }
                            ,{
                            'syn0': [],
                            'syn1': [],
                            'syn2': [],
                            'nots': []
                            }
                            ,...
                            ,{
                            'syn0': [],
                            'syn1': [],
                            'syn2': [],
                            'nots': []
                            }
                         ]
            }
        }

# %% [markdown]
# El atributo name sencillamente identifica el tema.
# El atributo wordset es el conjunto de palabras que identifican el tema. Su contenido se divide en dos piezas, los elementos "and" y los elementos "or". En el primer caso, todos los tokens que constituyen la lista de "ands" deben aparecer en el texto de la opinión (ya sea review o summary) con tal de que el algoritmo de búsqueda considere que se produce un hit. Los ors son el elemento más flexible. Es una lista de "grupos or". Cada grupo or contiene un concepto o bien una representación distinta de un mismo concepto, y el algoritmo de búsqueda considerará que se produce un hit si se satisface alguno de los grupos or.
#
# La estructura de cada grupo or está compuesta de 4 listas. Una lista de sinónimos de tipo 0. Estos tokens suelen ser bigramas. Los sinónimos de tipo 1 requieren de un complemento, los sinónimos de tipo 2. Los nots son los tokens que, si se detectan próximas a un sinónimo de tipo 0 o 1 anulan el hit. Lo veremos con un ejemplo.
#
# Vamos a ver el funcionamiento, tanto de los temas como del algoritmo de búsqueda, con unos ejemplos, pero primero veamos las opiniones sobre las que mostramos el funcionamiento:

# %%
odf_prueba = odf.loc[[148, 1455, 2689, 2849, 7213, 13890, 59018, 774310, 83236, 3161181, 5183314]]
for each in odf_prueba.iterrows():
    print('Opinión #', str(int(each[1]['doc_number']))+':')
    print('Rating:', str(int(each[1]['rating'])))
    print(each[1]['review_raw'], '\n\n********************************************\n')
# Out:
# Opinión # 148:
# Rating: 5
# Love my Nook Charger... rapid charging
#
# ********************************************
#
# Opinión # 1455:
# Rating: 2
# horribly built-in operating system and the cynegenmod is very unstable.  ok for watching moves though.
#
# ********************************************
#
# Opinión # 2689:
# Rating: 5
# Works great and provides a steady fast charger to all of your devices!!!!
#
# ********************************************
#
# Opinión # 2849:
# Rating: 1
# The good thing is I bought two - the bad thing is my plan to give one of them away was thwarted by one of them being defective. It lights-up but will not charge, any phone or tablet, from any outlet. UPDATE: The seller replaced the defective item at no charge.
#
# UPDATE: needed to charge my iPhone and iPad Mini at the same time - and was disappointed. The devices freaked-out and alternated between charging constantly until I unplugged one. So beware - it says it says 'dual charger' - BUT JUST NOT AT THE SAME TIME.
#
# ********************************************
#
# Opinión # 7213:
# Rating: 5
# Use it in the bedroom to extend my phone charger. I love the length.
#
# ********************************************
#
# Opinión # 13890:
# Rating: 1
# Awkward to use and the pieces  were difficult to put together (the padded ear cushion would NOT go on ... and no instructions were provided).  Uncomfortable on my head and basically more trouble than it was worth.  Will keep trying to find a good "plug-in" headset for my iPhone as an alternate to bluetooth.  My biggest problem was that it wasn't clear from the description that I HAD TO ALSO ORDER the 2.5 - 3.5 adapter in order for the plug to work with my iPhone 4.  Went all over trying to find such an item to no avail (even Best Buy didn't carry anything).  Trying to return it.
#
# ********************************************
#
# Opinión # 59018:
# Rating: 3
# This is a huge carrier. The inserts are flimsy.  Not as stable as I would have liked.  It will be a good holder to keep the CDs in the house, but I don't think it will travel well.
#
# ********************************************
#
# Opinión # 774310:
# Rating: 5
# I've bought 5 of these and have never had an issue with any of them.  I use these as phone charger extensions and they work fine with iPhone 6 so long as there isn't a certification issue with your lightning charger.  These are durable and long.  Very good quality for a great price.
#
# ********************************************
#
# Opinión # 83236:
# Rating: 1
# Does not work.  Will be returning.
#
# Right out of the package, this product did not work.  I plugged the splitter into my phone then tested each female connector with my headphones.  Bad, quiet, scratchy, inconsistent audio in one, and almost no audio in the other.  I tried connecting two sets of headphones, one into each connector.  Same result.
#
# Don't waste your time.
#
# ********************************************
#
# Opinión # 3161181:
# Rating: 1
# BEWARE:  Device is not Win 7 Plug and Play as advertised.  Have to download driver from their website with no instructions. Think about it. Your computer may not connect to the Internet and so you are buying this device. You may need another computer to connect to get the proper drivers and you may have to spend hours finding out what to do.  I am returning this.  Don't waste your time with a company that won't provide compatible drivers (preferably on CD) and proper instructions for buyer to use.  It is so simple to include drivers and instructions these days.
#
# ********************************************
#
# Opinión # 5183314:
# Rating: 5
# Plug and play simple, great inexpensive mouse!
#
# ********************************************

# %% [markdown]
# Veamos el funcionamiento del elemento "ands".

# %%
tema =  {
            'name': 'Prueba'
            , 'wordset':
            {
                'ands':  ['iphone']
                , 'ors': [
                            {
                            'syn0': [],
                            'syn1': [],
                            'syn2': [],
                            'nots': []
                            }
                         ]
            }
        }

# %%
utils.analize_wordset_not_so_naive_4(odf_prueba, tema, False)[0]['doc_number']
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Prueba ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 11 HITS: 0 ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________
# doc_number
# 2849        2849
# 13890      13890
# 774310    774310
# Name: doc_number, dtype: int64

# %% [markdown]
# Comprobamos que se han localizado las 3 opiniones en las que aparece el token 'iphone':

# %% [markdown]
# Verificamos que si añadimos un token a la lista de "ands", la búsqueda es más restrictiva, pues solo harán hit las opiniones que contengan ambos tokens.

# %%
tema =  {
            'name': 'Prueba'
            , 'wordset':
            {
                'ands':  ['iphone', 'charger']
                , 'ors': [
                            {
                            'syn0': [],
                            'syn1': [],
                            'syn2': [],
                            'nots': []
                            }
                         ]
            }
        }

# %%
utils.analize_wordset_not_so_naive_4(odf_prueba, tema, False)[0]['doc_number']
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Prueba ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 11 HITS: 0 ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________
# doc_number
# 2849        2849
# 774310    774310
# Name: doc_number, dtype: int64

# %% [markdown]
# Comprobamos que la opinión 13890 deja de aparecer, pues no contiene la palabra "charger".

# %% [markdown]
# A continuación buscaremos opiniones que contengan alguno de los dos tokens. Para ello empleamos la lista syn0 del grupo or.

# %%
tema =  {
            'name': 'Prueba'
            , 'wordset':
            {
                'ands':  []
                , 'ors': [
                            {
                            'syn0': ['iphone', 'charger'],
                            'syn1': [],
                            'syn2': [],
                            'nots': []
                            }
                         ]
            }
        }

# %%
utils.analize_wordset_not_so_naive_4(odf_prueba, tema, False)[0]['doc_number']
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Prueba ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 11 HITS: 1 ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________
# doc_number
# 148          148
# 2689        2689
# 2849        2849
# 7213        7213
# 13890      13890
# 774310    774310
# Name: doc_number, dtype: int64

# %% [markdown]
# En esta ocasión aparecen todas las opiniones que contiene alguna de las dos (o las dos) palabras.

# %% [markdown]
# Ahora probemos una búsqueda algo más avanzada. Consideraremos 'phone' y 'iphone' como sinónimos, y exigiremos que aparezca el token 'charger'.

# %%
tema =  {
            'name': 'Prueba'
            , 'wordset':
            {
                'ands':  ['charger']
                , 'ors': [
                            {
                            'syn0': ['iphone', 'phone'],
                            'syn1': [],
                            'syn2': [],
                            'nots': []
                            }
                         ]
            }
        }

# %%
utils.analize_wordset_not_so_naive_4(odf_prueba, tema, False)[0]['doc_number']
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Prueba ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 11 HITS: 0 ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________
# doc_number
# 2849        2849
# 7213        7213
# 774310    774310
# Name: doc_number, dtype: int64

# %% [markdown]
# Comprobamos que se trata del resultado esperado: la opinión 7213 contiene "charger" y "phone" y las otras dos contienen "charger" y "iphone".

# %% [markdown]
# En esta ocasión vamos a mostrar la diferencia entre los syn0 y los sin1/syn2. Definimos un tema que considere la inestabilidad del producto. Los syn0 serán 'unstable' y 'stability_issues', mientras que el syn1 será 'stable', apoyado por el complemento 'not'.

# %%
tema =  {
            'name': 'Prueba'
            , 'wordset':
            {
                'ands':  []
                , 'ors': [
                            {
                            'syn0': ['unstable',
                                     'stability_issues'],
                            'syn1': ['stable'],
                            'syn2': ['not'],
                            'nots': []
                            }
                         ]
            }
        }

# %%
utils.analize_wordset_not_so_naive_4(odf_prueba, tema, False)[0]['doc_number']
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Prueba ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 11 HITS: 0 ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________
# doc_number
# 1455      1455
# 59018    59018
# Name: doc_number, dtype: int64

# %% [markdown]
# Podemos comprobar fácilmente que ambas opiniones tratan el tema de la inestabilidad del producto.

# %% [markdown]
# Por último, veamos la importancia que puede tener el elemento 'not'. Para ello definimos dos temas iguales pero en uno de ellos le indicamos que los tokens 'not' y 'nor' no pueden aparecer próximos.

# %%
tema1 =  {
            'name': 'Prueba'
            , 'wordset':
            {
                'ands':  []
                , 'ors': [
                            {
                            'syn0': [],
                            'syn1': ['plug'],
                            'syn2': ['play'],
                            'nots': []
                            }
                         ]
            }
        }
tema2 =  {
            'name': 'Prueba'
            , 'wordset':
            {
                'ands':  []
                , 'ors': [
                            {
                            'syn0': [],
                            'syn1': ['plug'],
                            'syn2': ['play'],
                            'nots': ['not']
                            }
                         ]
            }
        }

# %%
utils.analize_wordset_not_so_naive_4(odf_prueba, tema1, False)[0]['doc_number']
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Prueba ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 11 HITS: 0 ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________
# doc_number
# 3161181    3161181
# 5183314    5183314
# Name: doc_number, dtype: int64

# %%
utils.analize_wordset_not_so_naive_4(odf_prueba, tema2, False)[0]['doc_number']
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Prueba ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 11 HITS: 0 ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________
# doc_number
# 5183314    5183314
# Name: doc_number, dtype: int64

# %% [markdown]
# Hasta aquí hemos visto cómo funcionan los temas una vez están definidos pero cómo los definimos? Mediante un proceso manual asistido por diversas herramientas para explorar los tokens del corpus.
#
# En primer lugar, es fundamental disponer del corpus del dataset, es decir, los tokens que aparecen en las opiniones, y también cuántas veces aparecen. Para ello se ha desarrollado una función cuyo retorno es un objeto similar a un Bag Of Words. Lanzamos una muestra a continuación. Además de retornar la lista completa, podemos pedirle que nos muestre, en forma de wordcloud, los tokens más frecuentes.

# %%
tokens = utils.generate_bow(odf, False, show=True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN GENERATE_BOW _______________________________________________________
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=50000 de 1532805 :::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=100000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=150000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=200000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=250000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=300000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=350000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=400000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=450000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=500000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=550000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=600000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=650000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=700000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=750000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=800000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=850000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=900000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=950000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=1000000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=1050000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=1100000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=1150000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE GENERANDO BOW: i=1200000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE GENERANDO BOW: i=1250000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE GENERANDO BOW: i=1300000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE GENERANDO BOW: i=1350000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE GENERANDO BOW: i=1400000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE GENERANDO BOW: i=1450000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE GENERANDO BOW: i=1500000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 06s :::: LISTA DE BIGRAMS FINALIZADA :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 46s ____ FIN FUNCIÓN GENERATE_BOW __________________________________________________________

# %% [markdown]
# Esa es la primera herramienta. Simplemente revisando manualmente los tokens más comunes es posible hacerse una idea de los temas que se tratan. Muchos de ellos no son útiles descontextualizados. Por ello, acudimos a los bigramas:

# %%
utils.extract_bigrams_from_bow(tokens).head()
# Out:
#           bigram  num_occurrences
# 0     five_stars            82520
# 1     four_stars            57679
# 2    three_stars            50847
# 3  sound_quality            50551
# 4    works_great            47946

# %% [markdown]
# Los bigramas nos ofrecen una visión mucho más contextualizada. Si bien muchos de ellos no pueden ser interpretados por sí solos, sí hay otros muchos que sí lo permiten.

# %% [markdown]
# La siguiente herramienta nos asiste en la interpretación de los tokens. Nos sirve para contextualizarlos y adquirir una noción de "qué se suele decir" allí donde se usan. La función get_close_words nos devuelve los tokens más frecuentes que se encuentran antes (a la izquierda) del token buscado y las que se encuentran detrás (a la derecha). Asimismo, se recoge el número de ocasiones que aparecen e información sobre la puntuación: la media y la desviación estándar de aquellas opiniones en las que se ha encontrado el token seguido o precedido de cada palabra:

# %%
utils.get_close_words_2(odf, 'not_work', max_distance=3, n_words=8)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN GET_CLOSE_WORDS ____________________________________________________
# 00h 00m 00s :::: BUCLE OPINIONES: i=0 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=50000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=100000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=150000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=200000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=250000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=300000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=350000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=400000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=450000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=500000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=550000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=600000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=650000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=700000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=750000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=800000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=850000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=900000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=950000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1000000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1050000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1100000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=1150000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=1200000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1250000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=1300000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=1350000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=1400000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 11s :::: BUCLE OPINIONES: i=1450000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=1500000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-20-b184c53fb6ed> in <module>
# ----> 1 utils.get_close_words_2(odf, 'not_work', max_distance=3, n_words=8)
#
# ~\OneDrive\MDS\S2 - TFM\tfm_reviews\core\composicion_estrellas\source\utils.py in get_close_words_2(df, word, max_distance, n_words)
#    1534
#    1535     df_antes = pd.DataFrame(list(zip(palabras_antes, ratings_antes)), columns = ['token', 'rating'])
# -> 1536     df_antes = df_antes.groupby('token').agg({'rating':[np.size, np.mean, np.std]}).fillna(0)
#    1537     df_antes = df_antes.drop(remove_stopwords_from_bow_2(df_antes, 'post'))
#    1538     df_antes.columns = ['num_occurrences', 'rating_mean', 'rating_sd']
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     504
#     505                 try:
# --> 506                     result = _agg(arg, _agg_1dim)
#     507                 except SpecificationError:
#     508
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     454                 result = OrderedDict()
#     455                 for fname, agg_how in arg.items():
# --> 456                     result[fname] = func(fname, agg_how)
#     457                 return result
#     458
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     438                         "nested dictionary is ambiguous " "in aggregation"
#     439                     )
# --> 440                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     441
#     442             def _agg_2dim(name, how):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     849             # but not the class list / tuple itself.
#     850             func_or_funcs = _maybe_mangle_lambdas(func_or_funcs)
# --> 851             ret = self._aggregate_multiple_funcs(func_or_funcs, (_level or 0) + 1)
#     852             if relabeling:
#     853                 ret.columns = columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     928                 obj._reset_cache()
#     929                 obj._selection = name
# --> 930             results[name] = obj.aggregate(func)
#     931
#     932         if any(isinstance(x, DataFrame) for x in results.values()):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     855             cyfunc = self._is_cython_func(func_or_funcs)
#     856             if cyfunc and not args and not kwargs:
# --> 857                 return getattr(self, cyfunc)()
#     858
#     859             if self.grouper.nkeys > 1:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     886
#     887         if len(output) == 0:
# --> 888             raise DataError("No numeric types to aggregate")
#     889
#     890         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
utils.get_close_words_2(odf, 'works_great', max_distance=3, n_words=8)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN GET_CLOSE_WORDS ____________________________________________________
# 00h 00m 01s :::: BUCLE OPINIONES: i=0 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=50000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=100000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=150000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=200000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=250000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=300000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=350000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=400000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=450000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=500000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=550000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=600000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=650000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=700000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=750000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE OPINIONES: i=800000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE OPINIONES: i=850000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=900000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=950000 DE 1532805 ::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 10s :::: BUCLE OPINIONES: i=1000000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1050000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1100000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1150000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1200000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1250000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1300000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1350000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1400000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1450000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: i=1500000 DE 1532805 :::::::::::::::::::::::::::::::::::::::::::::
# 00h 01m 20s ____ FIN FUNCIÓN GET_CLOSE_WORDS _______________________________________________________
# (            num_occurrences  rating_mean  rating_sd
#  token
#  great                3594.0     4.313022   0.920867
#  five_stars           2700.0     4.990370   0.158435
#  works                1508.0     4.019894   1.120895
#  product              1386.0     4.025253   1.131791
#  use                  1063.0     4.055503   1.049493
#  good                  989.0     4.108190   0.962571
#  four_stars            968.0     3.994835   0.106530
#  price                 858.0     4.405594   0.801729,
#         num_occurrences  rating_mean  rating_sd
#  token
#  use             1279.0     4.057076   1.112890
#  good            1142.0     4.129597   1.013848
#  easy            1132.0     4.314488   0.947817
#  great           1046.0     4.308795   0.979825
#  price            967.0     4.378490   0.881999
#  far              588.0     4.173469   1.041152
#  love             578.0     4.422145   0.977207
#  using            527.0     4.098672   1.089938)

# %% [markdown]
# Simplemente con esta función ya nos damos cuenta de que algunas palabras están fuertemente relacionadas con la puntuación de las opiniones, como podemos ver en estas dos ejecuciones.

# %% [markdown]
# Otra asistencia relacionada con la definición de los wordsets es la que nos ofrece la función busca_tokens. Esta función nos permite ver en qué bigramas aparece un token dado.

# %%
utils.busca_tokens(tokens, ['quality'])
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# ['image_quality',
#  'quality_control',
#  'hight_quality',
#  'quality_pixily',
#  'dubious_quality',
#  'highest_quality',
#  'redeemable_quality',
#  'higher_quality',
#  'exude_quality',
#  'build_quality',
#  'quality_controll',
#  'quality__',
#  'redeeming_quality',
#  'poor_quality',
#  'bulid_quality',
#  'quality',
#  'quality_materials',
#  'low_quality',
#  'poorest_quality',
#  'declining_quality',
#  'questionable_quality',
#  'quality_assurance',
#  'exudes_quality',
#  'lesser_quality',
#  'quality_deteriorates',
#  'sound_quality',
#  'tonal_quality',
#  'poorer_quality',
#  'quality_varies',
#  'quality___',
#  'picture_quality',
#  'piture_quality',
#  'high_quality',
#  'oozes_quality']

# %% [markdown]
# Estas son las herramientas que, combinadas entre ellas y con una cierta dedicación, me han permitido definir los wordsets de los temas.

# %% [markdown]
# ## Asignación de temas a opiniones (hits)

# %% [markdown]
# El mecanismo de asignación de temas a opiniones lo hemos visto en la sección anterior. Es un algoritmo que recibe como inputs el odf y el envoltorio del wordset que queremos analizar. Además, podemos indicarle si queremos visualizar el histograma de los resultados por puntuación.
#
# El código de la función analize_wordset está diseñado para seguir la siguiente lógica (la describimos de forma aproximada, ya que el código contiene matices para mejorar el rendimiento y la precisión):
#
# * para cada opinión en el odf:
#   * si se cumple la condición de los ands en el texto:
#     * ands_compliance = True
#     * si se cumple algún grupo or en el texto:
#       * ors_compliance = True
#   * si ands_compliance y ors_compliance:
#     * se produce un hit
#
# Algunos mecanismos que incluye el código para mejorar el rendimiento:
# * Primero se realiza la búsqueda sobre el summary. De no satisfacerse las condiciones, entonces se busca en la review.
# * No se procesa todo el texto (algunos son muy largos) sino que en primer lugar se localizan las posiciones de los tokens del wordset y entonces seleccionamos una porción del texto que los envuelve. De este modo reducimos drásticamente la longitud del texto a procesar. La porción de texto a estudiar se establece mediante un parámetro, max_distance, que se ha establecido en 3. Esto hace que el texto a estudiar sea, en muchas ocasiones, de tan solo 7 tokens.
#
# Algunos mecanismos para mejorar la precisión:
# * En la línea de establecer una distancia máxima de 3 tokens, esta es la distancia máxima a la que pueden estar los elementos syn1 y syn2 para ser contabilizados.
# * De los elementos not, por su naturaleza, solo se comprueba su existencia en las max_distance posiciones previas al token de interés, no en las posteriores.

# %%
tokens = utils.generate_bow(odf, False, show=False)
bigrams = utils.extract_bigrams_from_bow(tokens)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN GENERATE_BOW _______________________________________________________
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=50000 de 1532805 :::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: BUCLE GENERANDO BOW: i=100000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=150000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=200000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: BUCLE GENERANDO BOW: i=250000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 11s :::: BUCLE GENERANDO BOW: i=300000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 14s :::: BUCLE GENERANDO BOW: i=350000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 11s :::: BUCLE GENERANDO BOW: i=400000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 11s :::: BUCLE GENERANDO BOW: i=450000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 11s :::: BUCLE GENERANDO BOW: i=500000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 12s :::: BUCLE GENERANDO BOW: i=550000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=600000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=650000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=700000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 14s :::: BUCLE GENERANDO BOW: i=750000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=800000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 15s :::: BUCLE GENERANDO BOW: i=850000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=900000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=950000 de 1532805 ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=1000000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 14s :::: BUCLE GENERANDO BOW: i=1050000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=1100000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 12s :::: BUCLE GENERANDO BOW: i=1150000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=1200000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 16s :::: BUCLE GENERANDO BOW: i=1250000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=1300000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=1350000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 13s :::: BUCLE GENERANDO BOW: i=1400000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 12s :::: BUCLE GENERANDO BOW: i=1450000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 12s :::: BUCLE GENERANDO BOW: i=1500000 de 1532805 :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 08s :::: LISTA DE BIGRAMS FINALIZADA :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 01m 30s ____ FIN FUNCIÓN GENERATE_BOW __________________________________________________________

# %% [markdown]
# # Definición de temas y obtención de los hits

# %% [markdown]
# A continuación se muestran los temas que se han definido, así como el resultado de la función analize. Para cada caso, se mostrará un histograma donde podremos ver la distribución de los ratings.

# %%
wsw1_pos =   {
            'name':'Funcionamiento (POS)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # MUY POSITIVO
                    {
                    'syn0': ['works_great',
                             'works_flawlessly',
                             'works_perfectly',
                             'worked_perfectly',
                             'works_well'],
                    'syn1': [],
                    'syn2': [],
                    'nots': ['not']
                    }
                    # POSITIVO
                    ,{
                    'syn0': ['works_fine',
                             'good_job',
                             'working_properly',
                             'works_ok',
                             'work_properly',
                             'serves_purpose'],
                    'syn1': [],
                    'syn2': [],
                    'nots': ['not']
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['works'],
                    'syn2': ['expected'],
                    'nots': ['not']
                    }
                    # BAJO CONSUMO
                    ,{
                    'syn0': [],
                    'syn1': ['power_consumption'],
                    'syn2': ['low'],
                    'nots': []
                    }
                    ]
            }
        }
an1_pos_fil, an1_pos_agg = utils.analize_wordset_not_so_naive_4(odf, wsw1_pos, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Funcionamiento (POS) ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 09s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 7028 :::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 14536 ::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 22143 ::::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 29868 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 37665 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 45369 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 52629 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 60025 ::::::::::::::::::::::
# 00h 00m 26s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 66942 ::::::::::::::::::::::
# 00h 00m 26s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 74174 :::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 81344 :::::::::::::::::::::
# 00h 00m 22s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 88136 :::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 94740 :::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 101256 ::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 107257 ::::::::::::::::::::
# 00h 00m 06s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw1_neg =   {
            'name':'Funcionamiento (NEG)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # GENÉRICO, NO FUNCIONA DEBIDAMENTE
                    {
                    'syn0': ['not_work'],
                    'syn1': ['working_properly',
                             'work_properly'],
                    'syn2': ['not'],
                    'nots': []
                    }
                    ,{
                    'syn0': ['faulty',
                             'defective',
                             'fluke'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # PROBLEMAS DE ESTABILIDAD
                    ,{
                    'syn0': ['unstable',
                             'stability_issues'],
                    'syn1': ['stable'],
                    'syn2': ['not'],
                    'nots': []
                    },
                    {
                    'syn0': [],
                    'syn1': ['suddenly_stopped',
                             'stopped'],
                    'syn2': ['suddenly',
                             'working'],
                    'nots': []
                    },
                    {
                    'syn0': ['unreliable',
                             'works_intermittently'],
                    'syn1': ['reliable'],
                    'syn2': ['not'],
                    'nots': []
                    }
                    # DEJÓ DE FUNCIONAR O COMENZÓ A FUNCIONAR MAL
                    ,{
                    'syn0': [],
                    'syn1': ['quit_working',
                             'stopped_working',
                             'stopped_working',
                             'stop_working',
                             'quits_working',
                             'quitted_working'],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['within_week',
                             'within_weeks',
                             'week',
                             'weeks'],
                    'syn2': ['stopped_working',
                             'started',
                             'broke',
                             'quits_working',
                             'quitted_working'],
                    'nots': []
                    }
                    ,{
                    'syn0': ['obsolescence',
                             'short_life',
                             'never_worked'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # ALTO CONSUMO
                    ,{
                    'syn0': ['drains_battery',
                             'eat_batteries',
                             'eats_batteries',
                             'eating_batteries'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['power_consumption'],
                    'syn2': ['high'],
                    'nots': []
                    },
                    ]
            }
        }
an1_neg_fil, an1_neg_agg = utils.analize_wordset_not_so_naive_4(odf, wsw1_neg, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Funcionamiento (NEG) ::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 4531 :::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 9587 :::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 14658 ::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 19928 ::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 25060 ::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 30168 ::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 35148 ::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 39884 ::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 44763 ::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 49519 :::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 54620 :::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 59963 :::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 65107 :::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 70281 :::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 74857 :::::::::::::::::::::
# 00h 00m 06s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw2_pos =   {
            'name':'Características (POS)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # GENÉRICO APARIENCIA
                    #{
                    #'syn0': busca_tokens(tokens, ['looks']),
                    #'syn1': [],
                    #'syn2': [],
                    #'nots': []
                    #}
                    # BUENA CALIDAD DE PIEZAS MECÁNICAS Y COMPONENTES
                    {
                    'syn0': ['excellent_build',
                             'sturdy'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['well_made',
                             'quite_good',
                             'well_designed',
                             'excellent_product',
                             'high_quality'],
                    'syn1': ['build_quality',
                             'image_quality'],
                    'syn2': ['good',
                             'nice',
                             'high'],
                    'nots': []
                    },
                    {
                    'syn0': ['excellent_product',
                             'excellent_quality',
                             'excellent_results',
                             'excellent_sound'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['sounds_great'],
                    'syn1': ['sound_quality',
                             'audio_quality'],
                    'syn2': ['good',
                             'great',
                             'excellent'],
                    'nots': ['not']
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['picture_quality',
                             'image_quality'],
                    'syn2': ['good',
                             'great',
                             'excellent'],
                    'nots': ['not']
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['battery_life'],
                    'syn2': ['good',
                             'great',
                             'long',
                             'excellent'],
                    'nots': ['not']
                    }
                    # BUEN ASPECTO
                    ,{
                    'syn0': ['nice_looking'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # TAMAÑO ADECUADO
                    ,{
                    'syn0': ['fit_perfectly'],
                    'syn1': ['fit',
                             'fits'],
                    'syn2': ['good',
                             'perfectly',
                             'right'],
                    'nots': ['not']
                    }
                    ,{
                    'syn0': ['perfect_size'],
                    'syn1': ['size',
                             'length'],
                    'syn2': ['perfect'],
                    'nots': []
                    }
                    ]
            }
        }               
an2_pos_fil, an2_pos_agg = utils.analize_wordset_not_so_naive_4(odf, wsw2_pos, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Características (POS) :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 24s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 6764 :::::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 13638 ::::::::::::::::::::::
# 00h 00m 24s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 20573 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 27033 ::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 33496 ::::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 40429 ::::::::::::::::::::::
# 00h 00m 30s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 47306 ::::::::::::::::::::::
# 00h 00m 30s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 53986 ::::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 60422 ::::::::::::::::::::::
# 00h 00m 35s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 66451 :::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 73118 :::::::::::::::::::::
# 00h 00m 34s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 79839 :::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 87026 :::::::::::::::::::::
# 00h 00m 32s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 93821 :::::::::::::::::::::
# 00h 00m 37s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 99083 :::::::::::::::::::::
# 00h 00m 10s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 49s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw2_neg =   {
            'name':'Características (NEG)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # GENÉRICO APARIENCIA
                    #{
                    #'syn0': busca_tokens(tokens, ['looks']),
                    #'syn1': [],
                    #'syn2': [],
                    #'nots': []
                    #}
                    # MALA CALIDAD DE PIEZAS MECÁNICAS Y COMPONENTES
                    {
                    'syn0': utils.busca_tokens(tokens, ['defective']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['broke_apart',
                             'fell_apart',
                             'fall_apart',
                             'falling_apart',
                             'cheaply_made',
                             'cheap_plastic',
                             'poor_quality',
                             'bit_flimsy',
                             'defective_product',
                             'poorly_constructed'],
                    'syn1': ['melted'],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['feels_cheap',
                             'felt_cheap',
                             'cheap_feel',
                             'poorly_made',
                             'cheap_plastic',
                             'cheap_plastics',
                             'cheap_cardboard',
                             'cheap_feeling',
                             'cheap_construction',
                             'cheap_materials',
                             'cheap_material'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['build_quality'],
                    'syn2': ['bad'],
                    'nots': ['not']
                    }
                    ,{
                    'syn0': ['broke_within',
                             'easily_broken',
                             'breaks_easily',
                             'breaks_easy',
                             'breaks_every',
                             'breaks_quickly',
                             'broke_quickly',
                             'broke_shortly'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['sound_quality',
                             'audio_quality'],
                    'syn2': ['poor',
                             'bad'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['picture_quality',
                             'image_quality'],
                    'syn2': ['poor',
                             'bad'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['battery_life'],
                    'syn2': ['short'],
                    'nots': []
                    }
                    # DISEÑO PRESENTA FALLOS
                    ,{
                    'syn0': ['design_flaw',
                             'design_defect',
                             'design_weakness',
                             'flawed_design',
                             'poor_design'],
                    'syn1': ['serious_design'],
                    'syn2': ['flaw',
                             'flaws'],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['drawbacks']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['drawback']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # TAMAÑO INADECUADO
                    ,{
                    'syn0': [],
                    'syn1': ['fit',
                             'fits'],
                    'syn2': ['not',
                             'no'],
                    'nots': []
                    },
                    {
                    'syn0': [],
                    'syn1': ['big',
                             'small',
                             'long',
                             'short'],
                    'syn2': ['too',
                             'not_enough',
                             'way_too'],
                    'nots': []
                    },
                    {
                    'syn0': [],
                    'syn1': ['size',
                             'length'],
                    'syn2': ['wrong'],
                    'nots': ['no']
                    },
                    {
                    'syn0': ['too_short',
                             'too_long',
                             'not_fit',
                             'too_small',
                             'too_big',
                             'too_large'],
                    'syn1': ['long_enough'],
                    'syn2': ['not'],
                    'nots': []
                    }
                    ]
            }
        }               
an2_neg_fil, an2_neg_agg = utils.analize_wordset_not_so_naive_4(odf, wsw2_neg, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 41s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Características (NEG) :::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 48s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 9890 :::::::::::::::::::::::
# 00h 00m 45s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 20304 ::::::::::::::::::::::
# 00h 00m 45s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 30759 ::::::::::::::::::::::
# 00h 00m 58s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 40758 ::::::::::::::::::::::
# 00h 00m 51s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 51105 ::::::::::::::::::::::
# 00h 00m 52s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 61158 ::::::::::::::::::::::
# 00h 00m 49s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 71144 ::::::::::::::::::::::
# 00h 00m 48s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 81140 ::::::::::::::::::::::
# 00h 00m 47s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 90688 ::::::::::::::::::::::
# 00h 00m 45s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 99345 :::::::::::::::::::::
# 00h 00m 45s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 108741 ::::::::::::::::::::
# 00h 00m 42s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 118023 ::::::::::::::::::::
# 00h 00m 39s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 127507 ::::::::::::::::::::
# 00h 00m 38s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 136972 ::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 146743 ::::::::::::::::::::
# 00h 00m 10s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 04s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw3_pos =  {
            'name':'Comodidad/Sencillez (POS)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # PUESTA EN FUNCIONAMIENTO SENCILLA O RÁPIDA
                    {
                    'syn0': ['easy_install',
                             'easy_installation',
                             'easy_setup',
                             'installed_easily',
                             'quick_installation',
                             'plug_play'],
                    'syn1': ['plug'],
                    'syn2': ['play'],
                    'nots': []
                    #'nots': ['not', 'no']
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['installation',
                             'install',
                             'setup',
                             'installed'],
                    'syn2': ['easy',
                             'fast',
                             'quick',
                             'easily',
                             'smooth',
                             'breeze'],
                    'nots': []
                    #'nots': ['not', 'no']
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['installed'],
                    'syn2': ['easily',
                             'quickly'],
                    'nots': []
                    #'nots': ['not', 'no']
                    }
                    #,{
                    #'syn0': busca_tokens(tokens, ['install', 'installation', 'installed', 'setup']),
                    #'syn1': [],
                    #'syn2': [],
                    #'nots': []
                    #}
                    ,{
                    'syn0': ['plug_play'],
                    'syn1': ['plug'],
                    'syn2': ['play'],
                    'nots': []
                    }
                    # USO DEL MANUAL DE INSTRUCCIONES
                    ,{
                    #'syn0': ['followed_instructions', 'written_instructions', 'written_documentation', 'instruction_book', 'instruction_booklet', 'instruction_manual', 'instruction_manuals', 'instruction_sheet', 'instructions_included', 'instructions_say'],
                    'syn0': utils.busca_tokens(tokens, ['instructions']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['instruction']),
                    #'syn1': ['instructions'],
                    #'syn2': ['understand', 'unintelligible'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ]
            }
        }
an3_pos_fil, an3_pos_agg = utils.analize_wordset_not_so_naive_4(odf, wsw3_pos, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 23s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Comodidad/Sencillez (POS) :::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 3527 :::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 7967 :::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 12783 ::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 17285 ::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 21463 ::::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 25993 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 29972 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 33944 ::::::::::::::::::::::
# 00h 00m 26s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 38249 ::::::::::::::::::::::
# 00h 00m 26s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 42347 :::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 46376 :::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 50626 :::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 55244 :::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 59344 :::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 62089 :::::::::::::::::::::
# 00h 00m 07s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw3_neg =  {
            'name':'Comodidad/Sencillez (NEG)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # PUESTA EN FUNCIONAMIENTO COMPLICADA O LENTA
                    #{
                    #'syn0': busca_tokens(tokens, ['install', 'installation', 'installed', 'setup']),
                    #'syn1': [],
                    #'syn2': [],
                    #'nots': []
                    #}
                    {
                    'syn0': [],
                    'syn1': ['plug_play'],
                    'syn2': ['no',
                             'not'],
                    'nots': []
                    }
                    # PROBLEMAS CON EL MANUAL DE INSTRUCCIONES
                    ,{
                    'syn0': ['indecipherable_instructions',
                             'confusing_instructions',
                             'unclear_instructions',
                             'instructions_stink',
                             'chinglish_instructions',
                             'meager_instructions',
                             'incomplete_instructions',
                             'scant_instructions',
                             'engrish_instructions',
                             'clearer_instructions',
                             'conflicting_instructions',
                             'sparse_instructions',
                             'skimpy_instructions',
                             'cryptic_instructions',
                             'inadequate_instructions',
                             'vague_instructions',
                             'no_instructions',
                             'instructions_suck']
                    ,'syn1': ['instructions']
                    ,'syn2': ['understand',
                              'unintelligible']
                    ,'nots': []
                    }
                    ,{
                    'syn0': ['poor_instruction',
                             'cryptic_instruction'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # PRODUCTO DE DIFÍCIL USO, INCÓMODOS O CON ELEMENTOS DESAGRADABLES
                    ,{
                    'syn0': [],
                    'syn1': ['user_friendly'],
                    'syn2': ['not'],
                    'nots': []
                    }
                    ,{
                    'syn0': ['not_recognize'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['tricky',
                             'figure_out',
                             'figured_out',
                             'figuring_out'],
                    'syn1': ['trying'],
                    'syn2': ['work'],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['annoying']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['uncomfortable']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ]
            }
        }
an3_neg_fil, an3_neg_agg = utils.analize_wordset_not_so_naive_4(odf, wsw3_neg, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Comodidad/Sencillez (NEG) :::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 24s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 4420 :::::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 9190 :::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 13698 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 18102 ::::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 22392 ::::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 26826 ::::::::::::::::::::::
# 00h 00m 24s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 31042 ::::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 35151 ::::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 39162 ::::::::::::::::::::::
# 00h 00m 24s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 43066 :::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 47017 :::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 51398 :::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 55675 :::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 59801 :::::::::::::::::::::
# 00h 00m 23s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 62724 :::::::::::::::::::::
# 00h 00m 07s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw4 =  {
            'name':'Producto incorrecto'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # GENÉRICO. SE MENCIONA LA DESCRIPCION
                    #{
                    #'syn0': busca_tokens(tokens, ['description']),
                    #'syn1': [],
                    #'syn2': [],
                    #'nots': []
                    #}
                    # SE ENVÍA UN PRODUCTO EQUIVOCADO
                    {
                    'syn0': ['specifically_ordered',
                             'shipped_wrong'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # EL PRODUCTO NO ES EXACTAMENTE COMO SE DESCRIBE
                    ,{
                    'syn0': [],
                    'syn1': ['advertised'],
                    'syn2': ['exactly'],
                    'nots': ['not']
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['different_than'],
                    'syn2': ['advertised'],
                    'nots': []
                    }
                    ,{
                    'syn0': ['description_implied',
                             'description_incorrect',
                             'description_misleads',
                             'description_neglects',
                             'description_lies',
                             'description_boasts',
                             'description_incomplete',
                             'deceptive_description',
                             'description_states',
                             'description_indicates',
                             'inaccurate_description',
                             'false_description',
                             'description_stating',
                             'description_suggests',
                             'incomplete_description',
                             'description_claims',
                             'description_inaccurate',
                             'description_implies',
                             'improper_description',
                             'wrong_description',
                             'phony_description',
                             'description_omits',
                             'description_specifies',
                             'description_indicated',
                             'description_emphasizes',
                             'description_said',
                             'misleading_description',
                             'description_lists',
                             'description_stated',
                             'incorrect_description'],
                    'syn1': ['description'],
                    'syn2': ['incorrect'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['totally_different',
                             'entirely_different'],
                    'syn2': ['recieved',
                             'described',
                             'pictured',
                             'ordered'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['pictured',
                             'advertised',
                             'described'],
                    'syn2': ['not'],
                    'nots': []
                    }
                    ,{
                    'syn0': ['meet_expectation',
                             'meet_expectations',
                             'meeting_expectations',
                             'meets_expectations'],
                    'syn1': [],
                    'syn2': [],
                    'nots': ['not']
                    }
                    ]
            }
        }
an4_fil, an4_agg = utils.analize_wordset_not_so_naive_4(odf, wsw4, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Producto incorrecto :::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 1115 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 2330 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 3584 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 4804 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 5967 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 7128 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 8317 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 9453 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 10637 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 11751 :::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 12796 :::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 13970 :::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 15049 :::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 16272 :::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 17476 :::::::::::::::::::::
# 00h 00m 06s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw5 =  {
            'name':'Referencia a opiniones'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    {
                    'syn0': utils.busca_tokens(tokens, ['review']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['reviews']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['reviewer']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['reviewers']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ]
            }
        }   
an5_fil, an5_agg = utils.analize_wordset_not_so_naive_4(odf, wsw5, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Referencia a opiniones ::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 32s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 9094 :::::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 18419 ::::::::::::::::::::::
# 00h 00m 32s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 27576 ::::::::::::::::::::::
# 00h 00m 31s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 36329 ::::::::::::::::::::::
# 00h 00m 31s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 44653 ::::::::::::::::::::::
# 00h 00m 31s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 53145 ::::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 60801 ::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 67944 ::::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 75107 ::::::::::::::::::::::
# 00h 00m 27s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 81817 :::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 89010 :::::::::::::::::::::
# 00h 00m 28s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 96854 :::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 105223 ::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 113438 ::::::::::::::::::::
# 00h 00m 25s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 118517 ::::::::::::::::::::
# 00h 00m 08s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw6_pos =  {
            'name':'Envío/entrega/packaging (POS)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # PAQUETE Y PACKAGING
                    {
                    'syn0': ['fancy_packaging',
                             'glitzy_packaging',
                             'sealed_packaging',
                             'recyclable_packaging',
                             'free_packaging'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['nicely_packed',
                             'blister_packed',
                             'securely_packed',
                             'packed_nicely',
                             'neatly_packed',
                             'safely_packed'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,
                    {
                    'syn0': ['sealed_package',
                             'tidy_package'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # ENVÍO RÁPIDO
                    ,{
                    'syn0': ['timely_shipping',
                             'speedy_shipping',
                             'overnight_shipping',
                             'ships_quickly',
                             'shipped_fast',
                             'shipped_quickly',
                             'shipped_promptly'],
                    'syn1': ['shipping',
                             'delivery'],
                    'syn2': ['fast',
                             'quick',
                             'good'],
                    'nots': []
                    }
                    ,{
                    'syn0': ['shipped_immediately',
                             'fast_delivery',
                             'fast_service',
                             'fast_ship',
                             'fast_shipping',
                             'quick_delivery'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['arrived_timely',
                             'arrived_earlier',
                             'arrived_sooner',
                             'arrived_promptly'],
                    'syn1': ['arrived'],
                    'syn2': ['fast',
                             'quickly'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['shipment_arrived'],
                    'syn2': ['short_time'],
                    'nots': []
                    }
                    ]
            }
        }
an6_pos_fil, an6_pos_agg = utils.analize_wordset_not_so_naive_4(odf, wsw6_pos, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Envío/entrega/packaging (POS) :::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 687 ::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 1432 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 2245 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 3010 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 3767 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 4485 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 5159 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 5814 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 6498 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 7120 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 7692 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 8268 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 8735 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 9318 ::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 9947 ::::::::::::::::::::::
# 00h 00m 05s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw6_neg =  {
            'name':'Envío/entrega/packaging (NEG)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    # PAQUETE RECIBIDO EN MALAS CONDICIONES
                    {
                    'syn0': ['shipping_damage'],
                    'syn1': ['broken',
                             'damaged'],
                    'syn2': ['box',
                             'package'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['package',
                             'box'],
                    'syn2': ['missing'],
                    'nots': []
                    }
                    # GENÉRICO DE PAQUETE Y PACKAGING
                    ,{
                    'syn0': ['excessive_packaging',
                             'stupid_packaging',
                             'poor_packaging',
                             'lousy_packaging',
                             'wasteful_packaging'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['densely_packed',
                             'jam_packed',
                             'poorly_packed',
                             'improperly_packed',
                             'packed_tightly',
                             'loosely_packed',
                             'tightly_packed'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,
                    {
                    'syn0': ['incomplete_package'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    # ENVÍO LENTO
                    ,{
                    'syn0': [],
                    'syn1': ['shipping',
                             'delivery'],
                    'syn2': ['slow'],
                    'nots': []
                    }
                    ]
            }
        }
an6_neg_fil, an6_neg_agg = utils.analize_wordset_not_so_naive_4(odf, wsw6_neg, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Envío/entrega/packaging (NEG) :::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 186 ::::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 385 ::::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 590 ::::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 763 ::::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 929 ::::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 1102 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 1259 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 1428 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 1572 :::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 1735 ::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 1848 ::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 2009 ::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 2155 ::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 2305 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 2449 ::::::::::::::::::::::
# 00h 00m 05s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw7_pos =  {
            'name':'Devolución/Postventa (POS)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    {
                    'syn0': [],
                    'syn1': ['help_desk',
                             'customer_support',
                             'customer_service',
                             'tech_support',
                             'call_customer',
                             'called_customer'],
                    'syn2': ['great',
                             'good',
                             'excellent'
                             'helpful'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['warranty_service',
                             'manufacturer_warranty',
                             'warranty'],
                    'syn2': ['great',
                             'good',
                             'excellent'
                             'nice'],
                    'nots': []
                    }
                    ]
            }
        }
an7_pos_fil, an7_pos_agg = utils.analize_wordset_not_so_naive_4(odf, wsw7_pos, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Devolución/Postventa (POS) ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 362 ::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 797 ::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 1296 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 1753 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 2174 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 2668 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 3134 :::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 3601 :::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 4131 :::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 4600 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 5122 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 5670 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 6273 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 6782 ::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 7144 ::::::::::::::::::::::
# 00h 00m 05s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw7_neg =  {
            'name':'Devolución/Postventa (NEG)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    {
                    'syn0': [],
                    'syn1': ['help_desk',
                             'customer_support',
                             'customer_service',
                             'tech_support',
                             'call_customer',
                             'called_customer'],
                    'syn2': ['poor'],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['warranty_service',
                             'manufacturer_warranty',
                             'warranty'],
                    'syn2': ['poor',
                             'terrible',
                             'horrible'],
                    'nots': []
                    }
                    ]
            }
        }
an7_neg_fil, an7_neg_agg = utils.analize_wordset_not_so_naive_4(odf, wsw7_neg, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Devolución/Postventa (NEG) ::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 100 ::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 226 ::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 355 ::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 473 ::::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 585 ::::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 708 ::::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 796 ::::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 881 ::::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 983 ::::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 1074 ::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 1147 ::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 1245 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 1325 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 1417 ::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 1508 ::::::::::::::::::::::
# 00h 00m 05s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw8 =  {
            'name':'Precio'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    {
                    'syn0': utils.busca_tokens(tokens, ['price']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['priced']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['dollar']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['dollars']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['expensive']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['cheap', 'ridiculously_cheap', 'incredibly_cheap', 'super_cheap', 'kinda_cheap', 'relatively_cheap'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ]
            }
        }
an8_fil, an8_agg = utils.analize_wordset_not_so_naive_4(odf, wsw8, True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Precio ::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 35s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 21748 ::::::::::::::::::::::
# 00h 00m 36s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 43354 ::::::::::::::::::::::
# 00h 00m 35s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 64839 ::::::::::::::::::::::
# 00h 00m 34s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 85485 ::::::::::::::::::::::
# 00h 00m 34s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 105895 :::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 125239 :::::::::::::::::::::
# 00h 00m 32s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 143488 :::::::::::::::::::::
# 00h 00m 33s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 161137 :::::::::::::::::::::
# 00h 00m 30s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 177868 :::::::::::::::::::::
# 00h 00m 31s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 193913 ::::::::::::::::::::
# 00h 00m 30s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 209809 ::::::::::::::::::::
# 00h 00m 30s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 226320 ::::::::::::::::::::
# 00h 00m 30s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 242271 ::::::::::::::::::::
# 00h 00m 31s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 258648 ::::::::::::::::::::
# 00h 00m 29s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 273622 ::::::::::::::::::::
# 00h 00m 08s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw9_neg = {
            'name':'Sentimiento (NEG)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    {
                    'syn0': ['not_buy', 
                             'not_bother', 
                             'buyer_beware', 
                             'never_buy', 
                             'not_waste', 
                             'not_wast', 
                             'throw_away', 
                             'cannot_recommend', 
                             'wasted_money'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['return']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': utils.busca_tokens(tokens, ['returning']),
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['sent_back',
                             'send_back',
                             'sending_back',
                             'ship_back'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ]
            }
        }
an9_neg_fil, an9_neg_agg = utils.analize_wordset_not_so_naive_4(odf, wsw9_neg, show=True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN BUSCA_TOKENS _______________________________________________________
# 00h 00m 00s ____ FIN FUNCIÓN BUSCA_TOKENS __________________________________________________________
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Sentimiento (NEG) :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 5964 :::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 12639 ::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 19280 ::::::::::::::::::::::
# 00h 00m 24s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 26171 ::::::::::::::::::::::
# 00h 00m 22s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 32985 ::::::::::::::::::::::
# 00h 00m 22s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 40017 ::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 46937 ::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 53326 ::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 59916 ::::::::::::::::::::::
# 00h 00m 21s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 66465 :::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 73283 :::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 80280 :::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 87473 :::::::::::::::::::::
# 00h 00m 20s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 94328 :::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 99442 :::::::::::::::::::::
# 00h 00m 06s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %%
wsw9_pos = {
            'name':'Sentimiento (POS)'
            ,'wordset': 
            {
                'ands': [],
                'ors' :
                    [
                    {
                    'syn0': ['highly_recommend', 'definitely_recommend', 'no_complaints'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['great_value', 'good_value', 'good_deal', 'well_worth', 'totally_worth', 'definately_worth'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['wise_choice', 'good_choice', 'smart_choice', 'excellent_choice', 'best_choice'],
                    'syn1': [],
                    'syn2': [],
                    'nots': ['not']
                    }
                    ,{
                    'syn0': ['worth_every'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['excellent_product'],
                    'syn1': [],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': ['exceeds_expectations', 'greatly_exceeds', 'exceeds_expectation', 'far_exceeds'],
                    'syn1': ['pleasantly_surprised'],
                    'syn2': [],
                    'nots': []
                    }
                    ,{
                    'syn0': [],
                    'syn1': ['than_expected'],
                    'syn2': ['much_better', 'much', 'better'],
                    'nots': []
                    }
                    ]
            }
        }
an9_pos_fil, an9_pos_agg = utils.analize_wordset_not_so_naive_4(odf, wsw9_pos, show=True)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE _______________________________________
# 00h 00m 00s :::: WORDSET A ANALIZAR: Sentimiento (POS) :::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: ARRANCA EL BUCLE DE OPINIONES :::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE OPINIONES: NUM_DOCUMENTO=0 DE 1532805 HITS: 0 :::::::::::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=100000 DE 1532805 HITS: 2661 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=200000 DE 1532805 HITS: 5475 :::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=300000 DE 1532805 HITS: 8318 :::::::::::::::::::::::
# 00h 00m 19s :::: BUCLE OPINIONES: NUM_DOCUMENTO=400000 DE 1532805 HITS: 11019 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=500000 DE 1532805 HITS: 13649 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=600000 DE 1532805 HITS: 16234 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=700000 DE 1532805 HITS: 18715 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=800000 DE 1532805 HITS: 21093 ::::::::::::::::::::::
# 00h 00m 18s :::: BUCLE OPINIONES: NUM_DOCUMENTO=900000 DE 1532805 HITS: 23364 ::::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1000000 DE 1532805 HITS: 25546 :::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1100000 DE 1532805 HITS: 27624 :::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1200000 DE 1532805 HITS: 29858 :::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1300000 DE 1532805 HITS: 32071 :::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1400000 DE 1532805 HITS: 34233 :::::::::::::::::::::
# 00h 00m 17s :::: BUCLE OPINIONES: NUM_DOCUMENTO=1500000 DE 1532805 HITS: 35858 :::::::::::::::::::::
# 00h 00m 05s :::: FINALIZA EL BUCLE DE OPINIONES ::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s ____ FIN FUNCIÓN ANALIZE_WORDSET_NOT_SO_NAIVE __________________________________________

# %% [markdown]
# Al finalizar la generación de todos los hits, recogemos los resultados y los procesamos, generando las matrices cuyo análisis nos proporcionarán los insights que buscamos.

# %%
lista_resultados_busquedas = []
lista_resultados_busquedas.append({'name':wsw1_pos['name'], 'resultados': an1_pos_fil, 'agregados': an1_pos_agg})
lista_resultados_busquedas.append({'name':wsw1_neg['name'], 'resultados': an1_neg_fil, 'agregados': an1_neg_agg})
lista_resultados_busquedas.append({'name':wsw2_pos['name'], 'resultados': an2_pos_fil, 'agregados': an2_pos_agg})
lista_resultados_busquedas.append({'name':wsw2_neg['name'], 'resultados': an2_neg_fil, 'agregados': an2_neg_agg})
lista_resultados_busquedas.append({'name':wsw3_pos['name'], 'resultados': an3_pos_fil, 'agregados': an3_pos_agg})
lista_resultados_busquedas.append({'name':wsw3_neg['name'], 'resultados': an3_neg_fil, 'agregados': an3_neg_agg})
lista_resultados_busquedas.append({'name':wsw4['name'], 'resultados': an4_fil, 'agregados': an4_agg})
lista_resultados_busquedas.append({'name':wsw5['name'], 'resultados': an5_fil, 'agregados': an5_agg})
lista_resultados_busquedas.append({'name':wsw6_pos['name'], 'resultados': an6_pos_fil, 'agregados': an6_pos_agg})
lista_resultados_busquedas.append({'name':wsw6_neg['name'], 'resultados': an6_neg_fil, 'agregados': an6_neg_agg})
lista_resultados_busquedas.append({'name':wsw7_pos['name'], 'resultados': an7_pos_fil, 'agregados': an7_pos_agg})
lista_resultados_busquedas.append({'name':wsw7_neg['name'], 'resultados': an7_neg_fil, 'agregados': an7_neg_agg})
lista_resultados_busquedas.append({'name':wsw8['name'], 'resultados': an8_fil, 'agregados': an8_agg})
lista_resultados_busquedas.append({'name':wsw9_pos['name'], 'resultados': an9_pos_fil, 'agregados': an9_pos_agg})
lista_resultados_busquedas.append({'name':wsw9_neg['name'], 'resultados': an9_neg_fil, 'agregados': an9_neg_agg})

mat_doc_ws, mat_doc_ws_agg = utils.analize_wordset_occurrences(odf, lista_resultados_busquedas)
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN ANALIZE_WORDSET_OCCURRENCES ________________________________________
# 00h 00m 00s :::: SE PROCEDE A ANALIZAR EL WORDSET Funcionamiento (POS) :::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 109126 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=20000 de 109126 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=40000 de 109126 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=60000 de 109126 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=80000 de 109126 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=100000 de 109126 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 18s :::: SE PROCEDE A ANALIZAR EL WORDSET Funcionamiento (NEG) :::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 76488 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 34s :::: BUCLE: i=20000 de 76488 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 34s :::: BUCLE: i=40000 de 76488 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 35s :::: BUCLE: i=60000 de 76488 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 28s :::: SE PROCEDE A ANALIZAR EL WORDSET Características (POS) ::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 100973 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=20000 de 100973 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 42s :::: BUCLE: i=40000 de 100973 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=60000 de 100973 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=80000 de 100973 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=100000 de 100973 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s :::: SE PROCEDE A ANALIZAR EL WORDSET Características (NEG) ::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 150016 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=20000 de 150016 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=40000 de 150016 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=60000 de 150016 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 42s :::: BUCLE: i=80000 de 150016 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=100000 de 150016 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=120000 de 150016 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=140000 de 150016 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 20s :::: SE PROCEDE A ANALIZAR EL WORDSET Comodidad/Sencillez (POS) ::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 63265 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=20000 de 63265 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=40000 de 63265 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=60000 de 63265 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 06s :::: SE PROCEDE A ANALIZAR EL WORDSET Comodidad/Sencillez (NEG) ::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 63798 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=20000 de 63798 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=40000 de 63798 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=60000 de 63798 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 07s :::: SE PROCEDE A ANALIZAR EL WORDSET Producto incorrecto ::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 17880 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 31s :::: SE PROCEDE A ANALIZAR EL WORDSET Referencia a opiniones :::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 120539 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=20000 de 120539 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=40000 de 120539 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=60000 de 120539 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=80000 de 120539 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 42s :::: BUCLE: i=100000 de 120539 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=120000 de 120539 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s :::: SE PROCEDE A ANALIZAR EL WORDSET Envío/entrega/packaging (POS) ::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 10084 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 20s :::: SE PROCEDE A ANALIZAR EL WORDSET Envío/entrega/packaging (NEG) ::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 2506 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 04s :::: SE PROCEDE A ANALIZAR EL WORDSET Devolución/Postventa (POS) :::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 7261 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 14s :::: SE PROCEDE A ANALIZAR EL WORDSET Devolución/Postventa (NEG) :::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 1533 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 03s :::: SE PROCEDE A ANALIZAR EL WORDSET Precio :::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 278089 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=20000 de 278089 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=40000 de 278089 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=60000 de 278089 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=80000 de 278089 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 42s :::: BUCLE: i=100000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=120000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=140000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=160000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=180000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 41s :::: BUCLE: i=200000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=220000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=240000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 42s :::: BUCLE: i=260000 de 278089 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 37s :::: SE PROCEDE A ANALIZAR EL WORDSET Sentimiento (POS) ::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 36370 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 40s :::: BUCLE: i=20000 de 36370 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 34s :::: SE PROCEDE A ANALIZAR EL WORDSET Sentimiento (NEG) ::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: BUCLE: i=0 de 101381 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 35s :::: BUCLE: i=20000 de 101381 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 34s :::: BUCLE: i=40000 de 101381 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 34s :::: BUCLE: i=60000 de 101381 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 34s :::: BUCLE: i=80000 de 101381 ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 36s :::: BUCLE: i=100000 de 101381 :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# La ocupación parcial es del 49%
# La ocupación total es del 10%
# 00h 00m 05s ____ FIN FUNCIÓN ANALIZE_WORDSET_OCCURRENCES ___________________________________________

# %% [markdown]
# Vemos el porcentaje de opiniones sobre las que hemos conseguido al menos un hit. Se muestra un histograma donde se lee cuántas opiniones tratan qué cantidad de temas.
#
# Hay que destacar que los resultados que se han obtenido, y que se seguirán obteniendo en esta sección, se han cosechado con una metodología en base a palabras clave. Esto quiere decir que los resultados solo muestran aquellos hits que pueden producirse con esta estrategia y hay que tener esto en cuenta durante la interpretación.
#
# Una consecuencia posible del uso de esta técnica es, por ejemplo, que algunos temas estén muy poblados debido a que hay una expresión muy recurrente y muy propia de cierto tema. En el contexto del análisis de texto siempre hay múltiples maneras de expresar un mismo concepto, pero no todas las maneras son detectables mediante el uso de keywords. Considero, de todos modos, que los resultados obtenidos son acorde con lo que se espera y, por tanto, interpreto que el algoritmo analize es  efectivo en su propósito. El porcentaje de opiniones que quedan por asociar a un tema, así como las opinones en las que se han detectado menos temas de los que realmente deberían haberse detectado, es achacable a formas de expresar conceptos que no son detectables mediante keywords.

# %% [markdown]
# La primera pregunta que vamos a tratar de responder es: ¿de qué manera se relacionan las opiniones, los temas y las puntuaciones?
#
# Para ello, vamos a realizar una representación de tipo red, donde cada nodo es o bien una opinión o bien un tema y cada arista une una opinión con un tema, pudiendo haber varias aristas uniendo una opinión con un nodo. El color de las aristas representará la puntuación.
#
# El tiempo de respuesta de representar todas las opiniones individualmente es inaceptable, además de que se trata de una cantidad muy elevada y el resultado es un gráfico en el que no se aprecia apenas nada. Para solucionar este inconveniente, la representación se modifica de manera que se agrupan todas las opiniones equivalentes y todas ellas generan un solo nodo (el nodo en sí se muestra con un tamaño cero, pues lo interesante son las aristas). Las opiniones equivalentes son todas aquellas que son de la misma puntuación y tienen los mismos hits. El tamaño (grosor) de las aristas es proporcional al número de opiniones equivalentes que contienen los nodos.
#
# Veamos el aspecto:

# %%
utils.visualize_wordsets_network_6(mat_doc_ws, group_size=1000, k=0.3, ratings='F')
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN VISUALIZE_WORDSETS_NETWORK _________________________________________
# 00h 00m 01s :::: SE PROCEDE A GENERAR LA EDGELIST ::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: EDGELIST GENERADA. SE PROCEDE A GENERAR LA NODELIST :::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A POBLAR NODOS Y ARISTAS :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A CALCULAR POS :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A DIBUJAR LA RED :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s ____ FIN DE LA FUNCION VISUALIZE_WORDSETS_NETWORK ______________________________________

# %% [markdown]
# También puede verse por puntuación. Veamos las 5:

# %%
utils.visualize_wordsets_network_6(mat_doc_ws, group_size=500, k=0.3, ratings=[5])
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN VISUALIZE_WORDSETS_NETWORK _________________________________________
# 00h 00m 00s :::: SE PROCEDE A GENERAR LA EDGELIST ::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: EDGELIST GENERADA. SE PROCEDE A GENERAR LA NODELIST :::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A POBLAR NODOS Y ARISTAS :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A CALCULAR POS :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A DIBUJAR LA RED :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s ____ FIN DE LA FUNCION VISUALIZE_WORDSETS_NETWORK ______________________________________

# %%
utils.visualize_wordsets_network_6(mat_doc_ws, group_size=500, k=0.3, ratings=[4])
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN VISUALIZE_WORDSETS_NETWORK _________________________________________
# 00h 00m 00s :::: SE PROCEDE A GENERAR LA EDGELIST ::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: EDGELIST GENERADA. SE PROCEDE A GENERAR LA NODELIST :::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A POBLAR NODOS Y ARISTAS :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A CALCULAR POS :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A DIBUJAR LA RED :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s ____ FIN DE LA FUNCION VISUALIZE_WORDSETS_NETWORK ______________________________________

# %%
utils.visualize_wordsets_network_6(mat_doc_ws, group_size=500, k=0.3, ratings=[3])
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN VISUALIZE_WORDSETS_NETWORK _________________________________________
# 00h 00m 00s :::: SE PROCEDE A GENERAR LA EDGELIST ::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: EDGELIST GENERADA. SE PROCEDE A GENERAR LA NODELIST :::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A POBLAR NODOS Y ARISTAS :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A CALCULAR POS :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A DIBUJAR LA RED :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s ____ FIN DE LA FUNCION VISUALIZE_WORDSETS_NETWORK ______________________________________

# %%
utils.visualize_wordsets_network_6(mat_doc_ws, group_size=500, k=0.3, ratings=[2])
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN VISUALIZE_WORDSETS_NETWORK _________________________________________
# 00h 00m 00s :::: SE PROCEDE A GENERAR LA EDGELIST ::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: EDGELIST GENERADA. SE PROCEDE A GENERAR LA NODELIST :::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A POBLAR NODOS Y ARISTAS :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A CALCULAR POS :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A DIBUJAR LA RED :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s ____ FIN DE LA FUNCION VISUALIZE_WORDSETS_NETWORK ______________________________________

# %%
utils.visualize_wordsets_network_6(mat_doc_ws, group_size=500, k=0.3, ratings=[1])
# Out:
# 00h 00m 00s ____ INICIO FUNCIÓN VISUALIZE_WORDSETS_NETWORK _________________________________________
# 00h 00m 00s :::: SE PROCEDE A GENERAR LA EDGELIST ::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: EDGELIST GENERADA. SE PROCEDE A GENERAR LA NODELIST :::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A POBLAR NODOS Y ARISTAS :::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A CALCULAR POS :::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 00s :::: SE PROCEDE A DIBUJAR LA RED :::::::::::::::::::::::::::::::::::::::::::::::::::::::
# 00h 00m 01s ____ FIN DE LA FUNCION VISUALIZE_WORDSETS_NETWORK ______________________________________

# %% [markdown]
# Ya hemos observado qué aspecto tienen las relaciones. Se observan algunos temas muy unidos, especialmente para algunos rangos de puntuación, y otros menos.

# %% [markdown]
# La segunda pregunta que nos planteamos es ¿cómo de enlazados están los temas?. Ya se ha visto en las representaciones de red, pero veámoslo de forma cuantitativa. A continuación vemos la "matriz de compartición". Su objetivo es mostrar cuántas opiniones tienen en común un par de temas dado. La escala, con valores menores que la unidad, indica el porcentaje de opiniones que comparte. Evidentemente, el porcentaje de una pareja de temas no es simétrico, pues cada tema genera un volument total de hits distinto. Por ello, pese a que la matriz es simétrica si se representan los valores totales, cuando mostramos el ratio no lo es.

# %%
sm = utils.get_sharing_matrix(mat_doc_ws)

# %% [markdown]
# Para evitar que la diagonal eleve a 1 el máximo de la escala de color, he eliminado la diagonal, así se perciben mejor las diferencias de color entre las celdas de valor. Se observa que los dos temas más próximos, en términos de compartir opiniones, son sentimiento positivo y se menciona el precio.

# %% [markdown]
# En la celda siguiente representamos la cantidad de opiniones por tema y rating. Debe leerse en horizontal, pues la matriz se ha normalizado para cada tema.

# %%
utils.print_topic_heatmaps(mat_doc_ws)

# %% [markdown]
# En realidad, este heatmap es equivalente a representar, en un mismo espacio, cada uno de los histogramas que ya hemos visto más arriba, pintados por la función analize.

# %% [markdown]
# El siguiente heatmap se lee en vertical. Muestra, por cada puntuación, cuántos hits ha generado cada tema.

# %%
utils.print_rating_heatmaps(mat_doc_ws)

# %% [markdown]
# A continuación mostramos las 10 combinaciones más frecuentes.

# %%
utils.get_popular_topic_combinations(mat_doc_ws_agg, utils.get_wordsets_names(mat_doc_ws))
# Out:
#             0                       1                      2     3     4  \
# 57    14331.0  Referencia a opiniones                 Precio  None  None
# 417   13831.0   Características (NEG)                 Precio  None  None
# 686   13151.0   Características (POS)                 Precio  None  None
# 1806  10930.0    Funcionamiento (POS)                 Precio  None  None
# 1337   9293.0    Funcionamiento (NEG)  Características (NEG)  None  None
# 1      7577.0                  Precio      Sentimiento (NEG)  None  None
# 923    7368.0   Características (POS)  Características (NEG)  None  None
# 414    5828.0   Características (NEG)      Sentimiento (NEG)  None  None
# 54     5697.0  Referencia a opiniones      Sentimiento (NEG)  None  None
# 2      5529.0                  Precio      Sentimiento (POS)  None  None
#
#          5     6     7     8     9    10    11    12
# 57    None  None  None  None  None  None  None  None
# 417   None  None  None  None  None  None  None  None
# 686   None  None  None  None  None  None  None  None
# 1806  None  None  None  None  None  None  None  None
# 1337  None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None
# 923   None  None  None  None  None  None  None  None
# 414   None  None  None  None  None  None  None  None
# 54    None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None

# %% [markdown]
# En la tabla anterior se recoge el top 10 de combinaciones frecuentes. Este es un punto en el que puede verse muy claro el efecto de emplear palabras clave para generar hits. El tema del precio vemos que es muy recurrente, probablemente debido a que detectar keywords relacionadas con el mismo es muy sencillo.

# %% [markdown]
# A continuación comparamos las puntuaciones de aquellas opiniones que sí tratan un tema vs aquellas opiniones que no lo tratan. El color representa la puntuación media de las opiniones. La columna de No Hit, es decir las opiniones que no tratan del tema, la vemos muy pálida. Esto es porque, para cada tema, la mayoría de opiniones no tratan de él, por lo que la columna No Hit tiene un color muy próximo a la puntuación media.

# %%
utils.print_statistics_by_topic_heatmap_rating_value(mat_doc_ws)

# %% [markdown]
# El siguiente heatmap es complementario al anterior. Se visualiza la dispersión en las puntuaciones de cada tema.

# %%
utils.print_statistics_by_topic_heatmap_rating_sd(mat_doc_ws)

# %% [markdown]
# Por último veamos cómo responde el comprador a cada tema. El objetivo es ver cómo penaliza/beneficia cada tema.

# %%
utils.get_respuesta_comprador(lista_resultados_busquedas, mat_doc_ws)[['tema', 'slope_mod']]
# Out:
#                              tema  slope_mod
# 13              Sentimiento (POS)      0.107
# 8   Envío/entrega/packaging (POS)      0.095
# 0            Funcionamiento (POS)      0.074
# 2           Características (POS)      0.049
# 4       Comodidad/Sencillez (POS)      0.018
# 12                         Precio      0.016
# 10     Devolución/Postventa (POS)     -0.026
# 7          Referencia a opiniones     -0.030
# 5       Comodidad/Sencillez (NEG)     -0.031
# 6             Producto incorrecto     -0.060
# 3           Características (NEG)     -0.066
# 9   Envío/entrega/packaging (NEG)     -0.070
# 1            Funcionamiento (NEG)     -0.109
# 14              Sentimiento (NEG)     -0.113
# 11     Devolución/Postventa (NEG)     -0.125

# %% [markdown]
# El objetivo de esta tabla es doble. Por un lado, ver a qué temas responde mejor el comprador, en términos de rating, y cuáles penalizan más. Por otro lado, en aquellos temas dobles (los que tienen su versión positiva y su versión negativa) ver si está mejor recompensada la versión positiva o si penaliza más la versión negativa.
#
# Si descartamos los sentimientos, que no son temas per se, vemos que el tema mejor recompensado es el que refiere a Envío/entrega/packagin, incluso por encima del buen funcionamiento.
#
# Por la parte negativa, observamos que un mal servicio postventa es el tema que más penaliza, incluso más que un mal funciomaniento, probablemente debido a que un un consumidor que se ve obligado a hacer uso del servicio postventa no admite que este le suponga una mala experiencia.
